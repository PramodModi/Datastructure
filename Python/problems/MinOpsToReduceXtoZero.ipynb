# %% [markdown]
# ## Problem
# You are given an integer array nums and an integer x. In one operation, you can either remove the leftmost or the rightmost element from the array nums and subtract its value from x. Note that this modifies the array for future operations.
#
# Return the minimum number of operations to reduce x to exactly 0 if it is possible, otherwise, return -1.
#
# Example1:
#
# Input: nums = [1,1,4,2,3], x = 5
# Output: 2
# Explanation: The optimal solution is to remove the last two elements to reduce x to zero.
#
# Example:
#
# Input: nums = [5,6,7,8,9], x = 4
# Output: -1
#
# Example:
#
# Input: nums = [3,2,20,1,1,3], x = 10
# Output: 5
# Explanation: The optimal solution is to remove the last three elements and the first two elements (5 operations in total) to reduce x to zero.

# %%
def minOps(nums, X):
    i = 0
    m = len(nums)
    j = m-1
    count = 0
    while(i<j):
        print("leftnum = ", nums[i])
        print("righttnum = ", nums[j])
        print("X = ", X)
        left = X-nums[i]
        right = X-nums[j]
        
        if left>=0 and (left<=right or right <0):
            X = left
            i += 1
            count += 1
            print("count left= ", count)
        elif right>=0 and (right<left or left < 0):
            X = right
            j -= 1
            count += 1
            print("count right= ", count)
        else:
            return -1
        if X == 0:
            return count
    return -1

# %%
nums = [1,1,4,2,3]
X = 5
minOps(nums, X)
# Out:
# leftnum =  1
# righttnum =  3
# X =  5
# count right=  1
# leftnum =  1
# righttnum =  2
# X =  2
# count right=  2
# 2

# %%
nums = [5,6,7,8,9]
X = 4
minOps(nums, X)
# Out:
# leftnum =  5
# righttnum =  9
# X =  4
# -1

# %%
nums = [3,2,20,1,1,3]
X = 10
minOps(nums, X)
# Out:
# leftnum =  3
# righttnum =  3
# X =  10
# count left=  1
# leftnum =  2
# righttnum =  3
# X =  7
# count right=  2
# leftnum =  2
# righttnum =  1
# X =  4
# count left=  3
# leftnum =  20
# righttnum =  1
# X =  2
# count right=  4
# leftnum =  20
# righttnum =  1
# X =  1
# count right=  5
# 5

# %%
nums = [3,1,1,20,2,3]
X = 10
minOps(nums, X)
# Out:
# leftnum =  3
# righttnum =  3
# X =  10
# count left=  1
# leftnum =  1
# righttnum =  3
# X =  7
# count right=  2
# leftnum =  1
# righttnum =  2
# X =  4
# count right=  3
# leftnum =  1
# righttnum =  20
# X =  2
# count left=  4
# leftnum =  1
# righttnum =  20
# X =  1
# count left=  5
# 5

# %%
nums = [5207,5594,477,6938,8010,7606,2356,6349,3970,751,5997,6114,9903,3859,6900,7722,2378,1996,8902,228,4461,90,7321,7893,4879,9987,1146,8177,1073,7254,5088,402,4266,6443,3084,1403,5357,2565,3470,3639,9468,8932,3119,5839,8008,2712,2735,825,4236,3703,2711,530,9630,1521,2174,5027,4833,3483,445,8300,3194,8784,279,3097,1491,9864,4992,6164,2043,5364,9192,9649,9944,7230,7224,585,3722,5628,4833,8379,3967,5649,2554,5828,4331,3547,7847,5433,3394,4968,9983,3540,9224,6216,9665,807,3555,4198,2626,9553,9724,4503,1951,9980,3975,6025,8928,2952,911,3674,6620,3745,6548,4985,5206,5777,1908,6029,2322,2626,2188,5639]
X = 565610
minOps(nums, X)
# Out:
# leftnum =  5207
# righttnum =  5639
# X =  565610
# count right=  1
# leftnum =  5207
# righttnum =  2188
# X =  559971
# count left=  2
# leftnum =  5594
# righttnum =  2188
# X =  554764
# count left=  3
# leftnum =  477
# righttnum =  2188
# X =  549170
# count right=  4
# leftnum =  477
# righttnum =  2626
# X =  546982
# count right=  5
# leftnum =  477
# righttnum =  2322
# X =  544356
# count right=  6
# leftnum =  477
# righttnum =  6029
# X =  542034
# count right=  7
# leftnum =  477
# righttnum =  1908
# X =  536005
# count right=  8
# leftnum =  477
# righttnum =  5777
# X =  534097
# count right=  9
# leftnum =  477
# righttnum =  5206
# X =  528320
# count right=  10
# leftnum =  477
# righttnum =  4985
# X =  523114
# count right=  11
# leftnum =  477
# righttnum =  6548
# X =  518129
# count right=  12
# leftnum =  477
# righttnum =  3745
# X =  511581
# count right=  13
# leftnum =  477
# righttnum =  6620
# X =  507836
# count right=  14
# leftnum =  477
# ...
