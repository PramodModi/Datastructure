# %% [markdown]
# ## Problem:
#
# You're given the root node of a Binary Tree, a target value of a node that's contained in the tree,
# and a positive integer k . Write a function that returns the values of all the nodes that are exactly
# distance k from the node with target value.
# The distance between two nodes is defined as the number of edges that must be traversed to go from
# one node to the other. For example, the distance between a node and its immediate left or right child is
# 1 . The same holds in reverse: the distance between a node and its parent is 1 . In a tree of three
# nodes where the root node has a left and right child, the left and right children are distance 2 from
# each other.
# Each BinaryTree node has an integer value , a left child node, and a right child node.
# Children nodes can either be BinaryTree nodes themselves or None / null .
# Note that all BinaryTree node values will be unique, and your function can return the output values
# in any order.
#
# Example:
#
# tree =
#
#           1
#          /  \
#         2    3
#        / \    \
#       4   5    6
#               / \
#              7   8
#
# target = 3
#
# k = 2
#
# Output:
#
# [2, 7, 8] // These values could be ordered differently.

# %%
# This is an input class. Do not edit.
class BinaryTree:
    def __init__(self, value, left=None, right=None):
        self.value = value
        self.left = left
        self.right = right


def findNodesDistanceK(tree, target, k):
    # Write your code here.
    nodeList = []
    findNode(tree, target, k, nodeList)
    return nodeList
def findNode(node, target, k, nodeList):

    if node is None:
        return -1
    if node.value == target:
        findKDistanceNodes(node, 0, k, nodeList)
        return 1

    lefDistance = findNode(node.left, target, k, nodeList)
    rightDistance = findNode(node.right, target, k, nodeList)

    if lefDistance == k or rightDistance == k:
        nodeList.append(node.value)

    if lefDistance != -1:
        findKDistanceNodes(node.right, lefDistance + 1, k, nodeList)
        return lefDistance + 1
    if rightDistance != -1:
        findKDistanceNodes(node.left, rightDistance + 1, k, nodeList)
        return rightDistance + 1
    return -1

def findKDistanceNodes(node, distance, k, nodeList):
    if node is None:
        return
    if distance == k:
        nodeList.append(node.value)
        return

    findKDistanceNodes(node.left, distance + 1, k, nodeList)
    findKDistanceNodes(node.right, distance+1, k, nodeList)
