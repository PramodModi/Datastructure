# %%
# Exception class
class Empty(Exception):
    pass

# %%
class BST:
    # Node class for Tree
    class _Node:
         # Slots is being used to save memory and fster attribute access
        __slots__ = '_data','_left', '_right'
        
        def __init__(self, data):
            self._data = data
            self._left = None
            self._right = None
    
    def __init__(self):
        self._root = None
    
    # Insert new node in BST
    def insert(self, data):
        # Create new node
        newNode = self._Node(data)
        # If root is None, then its first node entry, Assign it to root
        if self._root is None:
            self._root = newNode
            return
        #Otherwise move down the tree. 
        #If data is lesser than root data, then go to the left otherwise go to the right
        tmp = self._root
        while tmp:
            x = tmp
            if data < tmp._data:
                tmp = tmp._left
            else: 
                tmp = tmp._right
        # Now assign the newnode to the left or right of the node, based on data.
        if data < x._data:
            x._left = newNode
        elif data > x._data:
            x._right = newNode
            
    # Get the node having minimum value.
    # Minimum value will be with left most node.
    def minValElement(self, root):
        
        tmp = root
        while tmp._left is not None:
            tmp = tmp._left
        return tmp
    
    # Get minimum vale in the tree
    def minVal(self):
        if self._root is None:
            raise Empty("Tree is Empty")
        return self.minValElement(self._root)._data
    
    # Get the node having maximum value.
    # Maximum value will be with right most node.
    def maxValEelment(self, root):
       
        tmp = root
        while tmp._right is not None:
            tmp = tmp._right
        return tmp
    
    # Get Maximum value in the tree
    def maxVal(self):
        if self._root is None:
            raise Empty("Tree is Empty")
        return self.maxValEelment(self._root)._data
   
    # find the node having given data. 
    #If data is less than root, then travers to left, otherwise right
    def find(self, data):
        if self._root is None:
            raise Empty("Tree is empty")
        tmp = self._root
        parent = None
        while (data < tmp._data):
            parent = tmp
            tmp = tmp._left
        while (data > tmp._data):
            parent = tmp
            tmp = tmp._right
        if data == tmp._data:
            return tmp, parent
        else:
            return None, None
        
    # Get predecessor of a given element
    def predecessor(self, e):
        # Find the node having element e. Find() will return None, if element is not available in the tree
        tmp, parent = self.find(e)
        if tmp is None:
            print("element is not available in tree")
            return
        # Find the very next smaller element from tmp
        # For smaller element, find right most element of first left element
        if tmp._left is None:
            return parent._data
        else:
            tmp = self.maxValEelment(tmp._left)
            return tmp._data
            
        
    
    # Traversals
    def _preorder(self, root):
        if root:
            print(root._data)
            self._preorder(root._left)
            self._preorder(root._right)
    def preorder(self):
        if self._root is None:
            raise Empty("Tree is empty")
        self._preorder(self._root)
        
    def _inorder(self, root):
        if root:
            self._inorder(root._left)
            print(root._data)
            self._inorder(root._right)
    
    def inorder(self):
        if self._root is None:
            raise Empty("Tree is empty")
        self._inorder(self._root)

# %%
b = BST()
b.insert(7)
b.insert(8)
b.insert(9)
b.insert(4)
b.insert(6)
b.insert(5)
b.insert(3)

print("Min Value : ", b.minVal())
print("Max Value : ", b.maxVal())
print("Predecessor of 9 : ", b.predecessor(9))
print("Predecessor of 8 : ", b.predecessor(8))
print("Predecessor of 7 : ", b.predecessor(7))
print("Predecessor of 4 : ", b.predecessor(4))
# Out:
# Min Value :  3
# Max Value :  9
# Predecessor of 9 :  8
# Predecessor of 8 :  7
# Predecessor of 7 :  6
# Predecessor of 4 :  3
